# %%
import numpy as np
import matplotlib.pyplot as plt

# REPLACE these with your actual x and y values from manual work
x = np.array([1,3], dtype=float)
y = np.array([3,6], dtype=float)

n = len(x)

# %%
m = -1   # initial slope (replace if different in your work)
b = 1   # initial intercept
alpha = 0.1  # learning rate (use the same you used manually)
iterations = 5

# %%
m_values = []
b_values = []
errors = []

for i in range(iterations):  # Should be 'iterations', not 'iteration'
    
    # Step 1: Predictions
    y_pred = m * x + b
    
    # Step 2: Error (Mean Squared Error with factor 1/2n to match manual calculation)
    error = np.sum((y - y_pred) ** 2) / (2 * n)  # ✓ Now matches J = (1/2n)Σ(eᵢ²)
    
    # Step 3: Gradients (matching your manual derivation)
    dm = (-1/n) * np.sum(x * (y - y_pred))   # ✓ ∂J/∂m = -(1/n)Σ(eᵢ·xᵢ)
    db = (-1/n) * np.sum(y - y_pred)         # ✓ ∂J/∂b = -(1/n)Σ(eᵢ)
    
    # Step 4: Update parameters
    m = m - alpha * dm
    b = b - alpha * db
    
    # Store values
    m_values.append(m)
    b_values.append(b)
    errors.append(error)
    
    # Print each step clearly
    print(f"Iteration {i+1}")
    print(f"  m = {m:.6f}")
    print(f"  b = {b:.6f}")
    print(f"  Error = {error:.8f}")
    print("-------------------------")
# Out:
# Iteration 1
#   m = 0.350000
#   b = 1.550000
#   Error = 18.25000000
# -------------------------
# Iteration 2
#   m = 0.915000
#   b = 1.775000
#   Error = 3.19250000
# -------------------------
# Iteration 3
#   m = 1.152500
#   b = 1.864500
#   Error = 0.57162500
# -------------------------
# Iteration 4
#   m = 1.253350
#   b = 1.897550
#   Error = 0.11499325
# -------------------------
# Iteration 5
#   m = 1.297165
#   b = 1.907125
#   Error = 0.03500214
# -------------------------

# %%
final_predictions = m * x + b

print("Final m:", m)
print("Final b:", b)
print("Final Predictions:", final_predictions)
# Out:
# Final m: 1.2971650000000001
# Final b: 1.9071250000000002
# Final Predictions: [3.20429 5.79862]

# %%
final_predictions = m * x + b

print("Final m:", m)
print("Final b:", b)
print("Final Predictions:", final_predictions)
# Out:
# Final m: 1.2971650000000001
# Final b: 1.9071250000000002
# Final Predictions: [3.20429 5.79862]

# %%
plt.figure()
plt.plot(m_values)
plt.plot(b_values)
plt.title("m and b over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Value")
plt.show()

# %%
plt.figure()
plt.plot(errors)
plt.title("Error over Iterations")
plt.xlabel("Iteration")
plt.ylabel("Error")
plt.show()
